# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("DentistryPGRs.csv")

# %%
df.head()
# Out:
#          Name  Student ID Programme code       Start         End        ESTS  \
# 0    Abdullah   200904222   PDM-OSPD-IFT  01/09/2015  31/10/2021  Registered
# 1        Adam   201386520    MSR-DENT-PT  01/09/2019  31/08/2021  Registered
# 2    Al Attal   201386186    DDP-PDEN-FT  01/09/2019  31/08/2023  Registered
# 3   Al-Jarjes   200843853    PHD-DENT-FT  01/03/2017  31/12/2021  Registered
# 4  Al-Shezawi   201088499    DDP-PDEN-FT  01/09/2017  31/08/2021  Registered
#
#                 Email                                      Project title  \
# 0   dnema@leeds.ac.uk  Factors involved in planning care pathway for ...
# 1   dnnad@leeds.ac.uk    Personality Differences in Dental Professionals
# 2  dnrzaa@leeds.ac.uk  Patients' views and experiences of genetic tes...
# 3  dnyaaj@leeds.ac.uk  The International Caries Detection and Assessm...
# 4  dnmasl@leeds.ac.uk  The effect of tea on surface loss of the denta...
#
# ...

# %%
plt.figure(figsize = (8,6))
sns.set_context("paper", font_scale=1.3)
ax = sns.displot(df['Main supervisor'])
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fig2 = plt.figure(figsize = (8,6))
sns.set_context("paper", font_scale=1.8)
ax = sns.displot(df['Type'])
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
fig2.savefig('PGRsnum.pdf')

# %%
plt.figure(figsize = (8,6))
sns.set_context("paper", font_scale=1.8)
ax = sns.displot(df['Fee status'])
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
# Out:
# [None, None, None, None, None, None]

# %%
#fig1=plt.figure(figsize=(6,4))
#plt.tight_layout()
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.6)
sns.swarmplot(x="Fee status", y="Type", data=df, hue="Mode", palette='prism')
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
plt.legend(bbox_to_anchor=(1, 1))
#fig1.savefig("PGRs.png") #output figure was cropped...

# %%
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.8)
sns.swarmplot(x="Mode", y="Type", data=df)
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
# Out:
# [None, None, None, None, None, None]

# %%
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.8)
sns.stripplot(x='Fee status', y='Type', data=df)
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
# Out:
# [None, None, None, None, None, None]

# %%
plt.figure(figsize = (8,6))
sns.set_context("paper", font_scale=1.8)
ax = sns.displot(df['Year of Study'])
